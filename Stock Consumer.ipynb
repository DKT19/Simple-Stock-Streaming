}
# {'Symbol': 'AAPL', 'Company': 'Apple Inc.', 'Price': '205.70', 'DayChange': '-3.04', 'Time': '09-04-2019 00:22:18'}
# {'Symbol': 'DIS', 'Company': 'The Walt Disney Company', 'Price': '136.31', 'DayChange': '-0.95', 'Time': '09-04-2019 00:22:18'}
# {'Symbol': 'MSFT', 'Company': 'Microsoft Corporation', 'Price': '136.04', 'DayChange': '-1.82', 'Time': '09-04-2019 00:22:18'}
# {'Symbol': 'AAPL', 'Company': 'Apple Inc.', 'Price': '205.70', 'DayChange': '-3.04', 'Time': '09-04-2019 00:27:18'}
# {'Symbol': 'DIS', 'Company': 'The Walt Disney Company', 'Price': '136.31', 'DayChange': '-0.95', 'Time': '09-04-2019 00:27:18'}
# {'Symbol': 'MSFT', 'Company': 'Microsoft Corporation', 'Price': '136.04', 'DayChange': '-1.82', 'Time': '09-04-2019 00:27:18'}
# {'Symbol': 'AAPL', 'Company': 'Apple Inc.', 'Price': '205.70', 'DayChange': '-3.04', 'Time': '09-04-2019 00:32:19'}
# {'Symbol': 'DIS', 'Company': 'The Walt Disney Company', 'Price': '136.31', 'DayChange': '-0.95', 'Time': '09-04-2019 00:32:19'}
# {'Symbol': 'MSFT', 'Company': 'Microsoft Corporation', 'Price': '136.04', 'DayChange': '-1.82', 'Time': '09-04-2019 00:32:19'}
# {'Symbol': 'AAPL', 'Company': 'Apple Inc.', 'Price': '205.70', 'DayChange': '-3.04', 'Time': '09-04-2019 00:37:20'}
# {'Symbol': 'DIS', 'Company': 'The Walt Disney Company', 'Price': '136.31', 'DayChange': '-0.95', 'Time': '09-04-2019 00:37:20'}
# {'Symbol': 'MSFT', 'Company': 'Microsoft Corporation', 'Price': '136.04', 'DayChange': '-1.82', 'Time': '09-04-2019 00:37:20'}
# {'Symbol': 'AAPL', 'Company': 'Apple Inc.', 'Price': '205.70', 'DayChange': '-3.04', 'Time': '09-04-2019 00:42:21'}
# {'Symbol': 'DIS', 'Company': 'The Walt Disney Company', 'Price': '136.31', 'DayChange': '-0.95', 'Time': '09-04-2019 00:42:21'}
# {'Symbol': 'MSFT', 'Company': 'Microsoft Corporation', 'Price': '136.04', 'DayChange': '-1.82', 'Time': '09-04-2019 00:42:21'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-34f2fe139a9d> in <module>
#      11 )
#      12
# ---> 13 for message in consumer:
#      14     message = message.value
#      15     print('{}'.format(message))
#
# ~\Miniconda3\envs\datascience\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1118         self._set_consumer_timeout()
#    1119         try:
# -> 1120             return next(self._iterator)
#    1121         except StopIteration:
#    1122             self._iterator = None
#
# ~\Miniconda3\envs\datascience\lib\site-packages\kafka\consumer\group.py in _message_generator(self)
#    1073             if not self._fetcher.in_flight_fetches():
#    1074                 poll_ms = min(poll_ms, self.config['reconnect_backoff_ms'])
# -> 1075             self._client.poll(timeout_ms=poll_ms)
#    1076
#    1077             # after the long poll, we should check whether the group needs to rebalance
#
# ~\Miniconda3\envs\datascience\lib\site-packages\kafka\client_async.py in poll(self, timeout_ms, future)
#     591                     timeout = max(0, timeout / 1000)  # avoid negative timeouts
#     592
# --> 593                 self._poll(timeout)
#     594
#     595                 responses.extend(self._fire_pending_completed_requests())
#
# ~\Miniconda3\envs\datascience\lib\site-packages\kafka\client_async.py in _poll(self, timeout)
#     612
#     613         start_select = time.time()
# --> 614         ready = self._selector.select(timeout)
#     615         end_select = time.time()
#     616         if self._sensors:
#
# ~\Miniconda3\envs\datascience\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# ~\Miniconda3\envs\datascience\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:
